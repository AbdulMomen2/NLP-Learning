# %%
import tensorflow as tf
import numpy as np

x = tf.range(-100,100,2)
x
y = x+10
y
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
x_train = x[:80]
y_train = y[:80]
x_test = x[80:]
y_test = y[80:]

# %%
plt.figure(figsize = (10,7))
plt.scatter(x_test,y_test, c='b', label = "Test Data")
plt.scatter(x_train,y_train, c='g', label = "Train Data")
plt.legend()

# %%
tf.random.set_seed(42)

#creating a model
model= tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation ="relu"),
    tf.keras.layers.Dense(100, activation ="relu"),
    tf.keras.layers.Dense(100, activation ="relu"),
    tf.keras.layers.Dense(100, activation ="relu"),
    tf.keras.layers.Dense(1)
])

#compiling model
model.compile(
    loss= tf.keras.losses.mae,
    optimizer = tf.keras.optimizers.Adam(),
    metrics = ["mae"]
)

# %%
x_train = tf.reshape(x_train, [-1, 1])

# %%
model.fit(x_train,y_train,epochs = 100)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 44.3643 - mae: 44.3643
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.2024 - mae: 39.2024
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.7121 - mae: 34.7121
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.0085 - mae: 30.0085
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.0032 - mae: 24.0032
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.1809 - mae: 16.1809
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8044 - mae: 6.8044
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5125 - mae: 8.5125
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8373 - mae: 8.8373
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3031 - mae: 5.3031
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5572 - mae: 5.5572
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8791 - mae: 5.8791
# ...

# %%
model.predict(np.array([100]))
y_pred = model.predict(x_test)
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# array([[ 69.892815],
#        [ 71.96445 ],
#        [ 74.03605 ],
#        [ 76.10767 ],
#        [ 78.17929 ],
#        [ 80.25091 ],
#        [ 82.32253 ],
#        [ 84.39415 ],
#        [ 86.46577 ],
#        [ 88.537384],
#        [ 90.609   ],
#        [ 92.680626],
#        [ 94.752235],
#        [ 96.82386 ],
#        [ 98.89547 ],
#        [100.967094],
#        [103.03871 ],
#        [105.11032 ],
#        [107.181946],
#        [109.25357 ]], dtype=float32)

# %%
plt.figure(figsize=(7,4))
plt.scatter(x_train,y_train,c='b', label = 'Tranning data')
plt.scatter(x_test,y_test,c='g', label = 'Testing data')
plt.scatter(x_test,y_pred,c='r', label = 'Predictions')
plt.legend()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 100)                 │             200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 100)                 │          10,100 │
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.5875 - mae: 0.5875
# [0.5874664187431335, 0.5874664187431335]

# %%
tf.constant(y_pred)
# Out:
# <tf.Tensor: shape=(20, 1), dtype=float32, numpy=
# array([[ 69.892815],
#        [ 71.96445 ],
#        [ 74.03605 ],
#        [ 76.10767 ],
#        [ 78.17929 ],
#        [ 80.25091 ],
#        [ 82.32253 ],
#        [ 84.39415 ],
#        [ 86.46577 ],
#        [ 88.537384],
#        [ 90.609   ],
#        [ 92.680626],
#        [ 94.752235],
#        [ 96.82386 ],
#        [ 98.89547 ],
#        [100.967094],
#        [103.03871 ],
#        [105.11032 ],
#        [107.181946],
#        [109.25357 ]], dtype=float32)>

# %%
y_test
# Out:
# <tf.Tensor: shape=(20,), dtype=int32, numpy=
# array([ 70,  72,  74,  76,  78,  80,  82,  84,  86,  88,  90,  92,  94,
#         96,  98, 100, 102, 104, 106, 108], dtype=int32)>

# %%
tf.squeeze(y_pred)
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([ 69.892815,  71.96445 ,  74.03605 ,  76.10767 ,  78.17929 ,
#         80.25091 ,  82.32253 ,  84.39415 ,  86.46577 ,  88.537384,
#         90.609   ,  92.680626,  94.752235,  96.82386 ,  98.89547 ,
#        100.967094, 103.03871 , 105.11032 , 107.181946, 109.25357 ],
#       dtype=float32)>

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_1 = tf.keras.models.load_model("/content/model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 100)                 │             200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 100)                 │          10,100 │
# ...
